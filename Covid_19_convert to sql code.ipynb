# %%
import pandas as pd
covid_vac = pd.read_excel('CovidVaccinations.xlsx')
covid_19 = pd.read_csv('covid_19.csv')
covid_deaths = pd.read_excel('CovidDeaths.xlsx')

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# personal information is hidden by '*'
username = 'root'
password = '******'
host = 'localhost'
port = *****
database = 'covid_dt'

engine = create_engine(f'mysql://{username}:{password}@{host}:{port}/{database}')

# %%
pip install mysqlclient
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
covid_19.to_sql('covid_19', engine, if_exists='replace', index=True)
covid_vac.to_sql('covid_vac', engine, if_exists='replace', index=True)
covid_deaths.to_sql('covid_deaths', engine, if_exists='replace', index=True)
# Out:
# 85171

# %%
covid_19 = pd.read_sql('covid_19', engine)
covid_19.head()
covid_19.columns
# Out:
# Index(['index', 'Province/State', 'Country/Region', 'Lat', 'Long', 'Date',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'WHO Region'],
#       dtype='object')

# %%
covid_vac = pd.read_sql('covid_vac', engine)
covid_vac.head()
# Out:
#    index iso_code continent     location       date  new_tests  total_tests  \
# 0      0      AFG      Asia  Afghanistan 2020-02-24        NaN          NaN
# 1      1      AFG      Asia  Afghanistan 2020-02-25        NaN          NaN
# 2      2      AFG      Asia  Afghanistan 2020-02-26        NaN          NaN
# 3      3      AFG      Asia  Afghanistan 2020-02-27        NaN          NaN
# 4      4      AFG      Asia  Afghanistan 2020-02-28        NaN          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  ...  \
# 0                       NaN                     NaN                 NaN  ...
# 1                       NaN                     NaN                 NaN  ...
# 2                       NaN                     NaN                 NaN  ...
# 3                       NaN                     NaN                 NaN  ...
# 4                       NaN                     NaN                 NaN  ...
#
# ...

# %%
covid_deaths = pd.read_sql('covid_deaths', engine)
covid_deaths.head()
# Out:
#    index iso_code continent     location       date  total_cases  new_cases  \
# 0      0      AFG      Asia  Afghanistan 2020-02-24          1.0        1.0
# 1      1      AFG      Asia  Afghanistan 2020-02-25          1.0        0.0
# 2      2      AFG      Asia  Afghanistan 2020-02-26          1.0        0.0
# 3      3      AFG      Asia  Afghanistan 2020-02-27          1.0        0.0
# 4      4      AFG      Asia  Afghanistan 2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  ...  gdp_per_capita  \
# 0                 NaN           NaN         NaN  ...        1803.987
# 1                 NaN           NaN         NaN  ...        1803.987
# 2                 NaN           NaN         NaN  ...        1803.987
# 3                 NaN           NaN         NaN  ...        1803.987
# 4                 NaN           NaN         NaN  ...        1803.987
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %%
covid_19
# Out:
#        index Province/State         Country/Region        Lat       Long  \
# 0          0           None            Afghanistan  33.939110  67.709953
# 1          1           None                Albania  41.153300  20.168300
# 2          2           None                Algeria  28.033900   1.659600
# 3          3           None                Andorra  42.506300   1.521800
# 4          4           None                 Angola -11.202700  17.873900
# ...      ...            ...                    ...        ...        ...
# 49063  49063           None  Sao Tome and Principe   0.186400   6.613100
# 49064  49064           None                  Yemen  15.552727  48.516388
# 49065  49065           None                Comoros -11.645500  43.333300
# 49066  49066           None             Tajikistan  38.861000  71.276100
# 49067  49067           None                Lesotho -29.610000  28.233600
#
#              Date  Confirmed  Deaths  Recovered  Active             WHO Region
# ...

# %%
covid_deaths.columns
# Out:
# Index(['index', 'iso_code', 'continent', 'location', 'date', 'total_cases',
#        'new_cases', 'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...
